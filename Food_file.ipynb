# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import seaborn

# %%
path=r'C:\Users\manish\Downloads\Food_demand_train_file\train.csv'
df=pd.read_csv(path)
# df.head(3)
df
# Out:
#              id  week  center_id  meal_id  checkout_price  base_price  \
# 0       1379560     1         55     1885          136.83      152.29
# 1       1466964     1         55     1993          136.83      135.83
# 2       1346989     1         55     2539          134.86      135.86
# 3       1338232     1         55     2139          339.50      437.53
# 4       1448490     1         55     2631          243.50      242.50
# ...         ...   ...        ...      ...             ...         ...
# 456543  1271326   145         61     1543          484.09      484.09
# 456544  1062036   145         61     2304          482.09      482.09
# 456545  1110849   145         61     2664          237.68      321.07
# 456546  1147725   145         61     2569          243.50      313.34
# 456547  1361984   145         61     2490          292.03      290.03
#
#         emailer_for_promotion  homepage_featured  num_orders
# 0                           0                  0         177
# ...

# %%
df.dtypes
# Out:
# id                         int64
# week                       int64
# center_id                  int64
# meal_id                    int64
# checkout_price           float64
# base_price               float64
# emailer_for_promotion      int64
# homepage_featured          int64
# num_orders                 int64
# dtype: object

# %%
df.groupby(['week'])['num_orders'].sum().sort_values(ascending = False).head(5).plot(kind = 'bar');

# %%
df
# Out:
#              id  week  center_id  meal_id  checkout_price  base_price  \
# 0       1379560     1         55     1885          136.83      152.29
# 1       1466964     1         55     1993          136.83      135.83
# 2       1346989     1         55     2539          134.86      135.86
# 3       1338232     1         55     2139          339.50      437.53
# 4       1448490     1         55     2631          243.50      242.50
# ...         ...   ...        ...      ...             ...         ...
# 456543  1271326   145         61     1543          484.09      484.09
# 456544  1062036   145         61     2304          482.09      482.09
# 456545  1110849   145         61     2664          237.68      321.07
# 456546  1147725   145         61     2569          243.50      313.34
# 456547  1361984   145         61     2490          292.03      290.03
#
#         emailer_for_promotion  homepage_featured  num_orders
# 0                           0                  0         177
# ...

# %%
df['week'].nunique()
# Out:
# 145

# %%
df1 = df[df['week'] == 52]

# %%
df1.groupby(['week','center_id'])['num_orders'].count().sort_values(ascending = False).head(10).plot(kind = 'bar')
# Out:
# <Axes: xlabel='week,center_id'>

# %%
dfdf[df['week'] == 52]
# Out:
#              id  week  center_id  meal_id  checkout_price  base_price  \
# 151796  1129709    52         55     1885          122.25      144.53
# 151797  1122337    52         55     1993          123.25      145.56
# 151798  1008737    52         55     2539          121.25      145.53
# 151799  1197758    52         55     2139          297.82      296.82
# 151800  1213679    52         55     2631          154.26      154.26
# ...         ...   ...        ...      ...             ...         ...
# 154984  1038900    52         61     1543          466.63      464.63
# 154985  1421350    52         61     2304          465.63      466.63
# 154986  1237683    52         61     2664          327.89      327.89
# 154987  1192712    52         61     2569          328.89      326.89
# 154988  1071343    52         61     2490          195.00      242.50
#
#         emailer_for_promotion  homepage_featured  num_orders
# 151796                      1                  1         406
# ...

# %%
df.sample(2)
# Out:
#              id  week  center_id  meal_id  checkout_price  base_price  \
# 418351  1217176   134         36     1885          150.35      151.35
# 296541  1302644    97        109     2492          293.00      389.03
#
#         emailer_for_promotion  homepage_featured  num_orders
# 418351                      0                  0        1093
# 296541                      0                  0          95

# %%
df['discount_percent'] = round((abs(df['base_price'] - df['checkout_price']) / df['base_price']) * 100,2)

# %%
df['meal_id'].unique()
# Out:
# array([1885, 1993, 2539, 2139, 2631, 1248, 1778, 1062, 2707, 1207, 1230,
#        2322, 2290, 1727, 1109, 2640, 2306, 2126, 2826, 1754, 1971, 1902,
#        1311, 1803, 1558, 2581, 1962, 1445, 2444, 2867, 1525, 2704, 2304,
#        2577, 1878, 1216, 1247, 1770, 1198, 1438, 2494, 1847, 2760, 2492,
#        1543, 2664, 2569, 2490, 1571, 2956, 2104], dtype=int64)

# %%
df.groupby(['meal_id'])['discount_percent']
# Out:
# meal_id
# 1438    28.47
# 2494    28.47
# 1847    28.84
# 1993    33.40
# 1525    33.64
# 2704    33.67
# 2640    34.56
# 2577    35.11
# 1962    37.34
# 2104    38.21
# 2581    40.32
# 1558    40.48
# 1062    41.35
# 1885    41.48
# 2664    44.40
# 1778    44.93
# 1445    45.34
# 2867    45.42
# 1878    49.38
# 2956    49.83
# 1247    50.00
# 1571    50.00
# 2569    50.99
# 1971    51.46
# 2490    52.39
# 2539    52.59
# 2290    52.96
# 2826    53.70
# 2126    54.27
# 2707    58.40
# 2760    59.84
# 2322    60.37
# 1216    61.92
# 1902    62.04
# 1727    65.60
# 2139    67.86
# 2304    69.30
# 1207    71.07
# 1543    71.16
# 1754    71.57
# 1311    75.22
# 2306    76.73
# 2492    78.09
# 1803    79.31
# 2444    79.42
# 1770    79.59
# 1198    79.63
# 2631    81.21
# 1248    81.98
# 1109    82.37
# 1230    99.06
# Name: discount_percent, dtype: float64

# %%
df['meal_id'].nunique()
# Out:
# 51

# %%
dff = df.groupby(['center_id','meal_id'])['discount_percent'].mean().reset_index()
dff
# Out:
#       center_id  meal_id  discount_percent
# 0            10     1062          3.905655
# 1            10     1109          8.844069
# 2            10     1198         10.526069
# 3            10     1207          9.644028
# 4            10     1216          5.076573
# ...         ...      ...               ...
# 3592        186     2707          3.523172
# 3593        186     2760          5.552199
# 3594        186     2826          3.834755
# 3595        186     2867          9.398283
# 3596        186     2956          1.949111
#
# [3597 rows x 3 columns]

# %%
#dff['center_id'].nunique()
df['center_id'].nunique()
# Out:
# 77

# %%
df[df['meal_id'] == 1230]
# Out:
#              id  week  center_id  meal_id  checkout_price  base_price  \
# 10      1469367     1         55     1230          323.01      390.00
# 43      1292501     1         24     1230          336.65      390.00
# 87      1039023     1         11     1230          325.98      380.30
# 128     1025380     1         83     1230          319.13      320.13
# 167     1488872     1         32     1230          317.19      317.19
# ...         ...   ...        ...      ...             ...         ...
# 456339  1094198   145         23     1230          379.27      381.27
# 456383  1462390   145         86     1230          378.30      378.30
# 456423  1350877   145         68     1230          309.43      357.99
# 456467  1289257   145         51     1230          370.57      370.57
# 456517  1209558   145         61     1230          368.63      367.63
#
#         emailer_for_promotion  homepage_featured  num_orders  discount_percent
# ...

# %%
round(100 - ((323/390) * 100),2)
# Out:
# 17.18

# %%
abs(round(100 - (df['checkout_price'] / df['base_price']) * 100,2))
# Out:
# 0         10.15
# 1          0.74
# 2          0.74
# 3         22.41
# 4          0.41
#           ...
# 456543     0.00
# 456544     0.00
# 456545    25.97
# 456546    22.29
# 456547     0.69
# Length: 456548, dtype: float64

# %%
round((abs(df['base_price'] - df['checkout_price']) / df['base_price']) * 100,2)

# %%
df
# Out:
#              id  week  center_id  meal_id  checkout_price  base_price  \
# 0       1379560     1         55     1885          136.83      152.29
# 1       1466964     1         55     1993          136.83      135.83
# 2       1346989     1         55     2539          134.86      135.86
# 3       1338232     1         55     2139          339.50      437.53
# 4       1448490     1         55     2631          243.50      242.50
# ...         ...   ...        ...      ...             ...         ...
# 456543  1271326   145         61     1543          484.09      484.09
# 456544  1062036   145         61     2304          482.09      482.09
# 456545  1110849   145         61     2664          237.68      321.07
# 456546  1147725   145         61     2569          243.50      313.34
# 456547  1361984   145         61     2490          292.03      290.03
#
#         emailer_for_promotion  homepage_featured  num_orders  discount_percent
# ...

# %%
new = df[df['meal_id'] == 1230]

# %%
new.sample(2)
# Out:
#              id  week  center_id  meal_id  checkout_price  base_price  \
# 108589  1168525    38         55     1230          475.33      476.33
# 234164  1242060    77        102     1230          314.31      313.31
#
#         emailer_for_promotion  homepage_featured  num_orders  discount_percent
# 108589                      0                  0          15              0.21
# 234164                      0                  0         161              0.32

# %%
new.groupby(['meal_id','center_id'])['num_orders'].count().sort_values()
# Out:
# meal_id  center_id
# 1230     91            13
#          24           115
#          20           131
#          76           131
#          64           132
#                      ...
#          177          145
#          102          145
#          83           145
#          58           145
#          10           145
# Name: num_orders, Length: 77, dtype: int64

# %%
new[new['center_id'] == 24]
# Out:
#              id  week  center_id  meal_id  checkout_price  base_price  \
# 43      1292501     1         24     1230          336.65      390.00
# 2964    1151324     2         24     1230          321.10      389.00
# 5860    1056917     3         24     1230          322.04      388.00
# 8757    1099465     4         24     1230          324.04      388.00
# 84316   1197942    30         24     1230          380.30      380.30
# ...         ...   ...        ...      ...             ...         ...
# 440217  1051737   141         24     1230          389.00      388.00
# 443475  1438410   142         24     1230          389.00      389.00
# 446719  1133532   143         24     1230          381.24      380.24
# 450024  1381717   144         24     1230          384.15      385.15
# 453323  1297849   145         24     1230          377.36      377.36
#
#         emailer_for_promotion  homepage_featured  num_orders  discount_percent
# ...

# %%
new[new['center_id'] == 73]
# Out:
#              id  week  center_id  meal_id  checkout_price  base_price  \
# 30199   1413141    11         73     1230          313.37      312.37
# 33062   1020667    12         73     1230          325.98      325.98
# 35887   1064953    13         73     1230          312.34      314.34
# 38724   1460563    14         73     1230          317.19      318.19
# 41570   1163285    15         73     1230          320.13      319.13
# ...         ...   ...        ...      ...             ...         ...
# 442022  1385193   141         73     1230          367.63      367.63
# 445272  1454255   142         73     1230          361.87      361.87
# 448546  1146971   143         73     1230          350.20      349.20
# 451852  1071772   144         73     1230          367.63      369.63
# 455135  1285046   145         73     1230          356.96      356.96
#
#         emailer_for_promotion  homepage_featured  num_orders  discount_percent
# ...
